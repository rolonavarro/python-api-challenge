# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#url

url="http://api.openweathermap.org/data/2.5/weather?q="

URL = f"{url}{cities}&appid={weather_api_key}"

# %%
# Create a base url
base_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# Counters
city_counter = 1
set_counter = 1

# Create the lists to hold relative data
cities_list= []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

print("Started")

# Create a query url for each city in the cities list to get json response
for i, city in enumerate(cities):
    
    # Group cities as sets of 50s
    if (i % 50 == 0 and i >= 50):
        set_counter += 1
        city_counter = 1
         
    # Create API url for each city
    query_url = base_url +"&q=" + city
    
    # Get json respose for each city
    response = requests.get(query_url).json()
    
    # Print the results 
    print(f"Processing Record {city_counter} of Set {set_counter} | {city}")
    
    # Increase city counter
    city_counter += 1
    
   # Add the values to the lists
    try:       
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        cities_list.append(response["name"])
    except:
        print("City not found. Skipping...")
        pass
        
print("Completed")
# Out:
# Started
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | tessalit
# Processing Record 3 of Set 1 | klaksvik
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | neuquen
# Processing Record 6 of Set 1 | mahibadhoo
# Processing Record 7 of Set 1 | cabedelo
# Processing Record 8 of Set 1 | chabahar
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | sakakah
# Processing Record 11 of Set 1 | nome
# Processing Record 12 of Set 1 | general pico
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | noumea
# Processing Record 17 of Set 1 | ngunguru
# Processing Record 18 of Set 1 | metkovic
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | methoni
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | praya
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | bathsheba
# Processing Record 29 of Set 1 | kasangulu
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | katsuura
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | acarau
# Processing Record 38 of Set 1 | boyolangu
# Processing Record 39 of Set 1 | te anau
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | codrington
# Processing Record 43 of Set 1 | sao jose da coroa grande
# Processing Record 44 of Set 1 | burgos
# Processing Record 45 of Set 1 | hithadhoo
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | poum
# Processing Record 48 of Set 1 | poya
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | san carlos de bariloche
# Processing Record 1 of Set 2 | ewa beach
# Processing Record 2 of Set 2 | kaka
# Processing Record 3 of Set 2 | pevek
# Processing Record 4 of Set 2 | marsh harbour
# Processing Record 5 of Set 2 | valle del guamuez
# Processing Record 6 of Set 2 | tombouctou
# Processing Record 7 of Set 2 | templemore
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | mahebourg
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | bundaberg
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | hovd
# Processing Record 15 of Set 2 | gravdal
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | dingle
# Processing Record 19 of Set 2 | vila franca do campo
# Processing Record 20 of Set 2 | chokurdakh
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | staraya poltavka
# Processing Record 24 of Set 2 | nerchinsk
# Processing Record 25 of Set 2 | ilave
# Processing Record 26 of Set 2 | santa rita
# Processing Record 27 of Set 2 | watsa
# Processing Record 28 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 2 | port macquarie
# Processing Record 30 of Set 2 | northam
# Processing Record 31 of Set 2 | lagoa
# Processing Record 32 of Set 2 | talnakh
# Processing Record 33 of Set 2 | smiths falls
# Processing Record 34 of Set 2 | norman wells
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | ushtobe
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | great yarmouth
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | ribeira brava
# Processing Record 41 of Set 2 | maniitsoq
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | potosi
# Processing Record 44 of Set 2 | milingimbi
# City not found. Skipping...
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | mihaileni
# Processing Record 47 of Set 2 | iqaluit
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 2 | alekseyevsk
# Processing Record 1 of Set 3 | carnarvon
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | porto novo
# Processing Record 4 of Set 3 | scalea
# Processing Record 5 of Set 3 | amudat
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | hami
# Processing Record 8 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 9 of Set 3 | torbay
# Processing Record 10 of Set 3 | yinchuan
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | waingapu
# Processing Record 13 of Set 3 | vila velha
# Processing Record 14 of Set 3 | kavaratti
# Processing Record 15 of Set 3 | san patricio
# Processing Record 16 of Set 3 | boyuibe
# Processing Record 17 of Set 3 | wanning
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 3 | rawson
# Processing Record 21 of Set 3 | tripoli
# Processing Record 22 of Set 3 | abrau-dyurso
# Processing Record 23 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | rocha
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 3 | ketchikan
# Processing Record 30 of Set 3 | bagotville
# Processing Record 31 of Set 3 | stornoway
# Processing Record 32 of Set 3 | clyde river
# Processing Record 33 of Set 3 | kawalu
# Processing Record 34 of Set 3 | komsomolskiy
# Processing Record 35 of Set 3 | inirida
# Processing Record 36 of Set 3 | hobyo
# Processing Record 37 of Set 3 | kaeo
# Processing Record 38 of Set 3 | los llanos de aridane
# Processing Record 39 of Set 3 | tir pol
# City not found. Skipping...
# Processing Record 40 of Set 3 | pacific grove
# Processing Record 41 of Set 3 | bredasdorp
# Processing Record 42 of Set 3 | nyurba
# Processing Record 43 of Set 3 | nabire
# Processing Record 44 of Set 3 | vila
# Processing Record 45 of Set 3 | krasnoselkup
# Processing Record 46 of Set 3 | larap
# Processing Record 47 of Set 3 | muros
# Processing Record 48 of Set 3 | vila do maio
# Processing Record 49 of Set 3 | colac
# Processing Record 50 of Set 3 | kemijarvi
# Processing Record 1 of Set 4 | souillac
# Processing Record 2 of Set 4 | emerald
# Processing Record 3 of Set 4 | florianopolis
# Processing Record 4 of Set 4 | thompson
# Processing Record 5 of Set 4 | lebu
# Processing Record 6 of Set 4 | atherton
# Processing Record 7 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 4 | havre-saint-pierre
# Processing Record 9 of Set 4 | armash
# Processing Record 10 of Set 4 | provideniya
# Processing Record 11 of Set 4 | luwuk
# Processing Record 12 of Set 4 | amos
# Processing Record 13 of Set 4 | alta floresta
# Processing Record 14 of Set 4 | saskylakh
# Processing Record 15 of Set 4 | draper
# Processing Record 16 of Set 4 | airai
# Processing Record 17 of Set 4 | alihe
# Processing Record 18 of Set 4 | benidorm
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | soto la marina
# Processing Record 21 of Set 4 | merauke
# Processing Record 22 of Set 4 | tabory
# Processing Record 23 of Set 4 | portales
# Processing Record 24 of Set 4 | astoria
# Processing Record 25 of Set 4 | lahij
# Processing Record 26 of Set 4 | dikson
# Processing Record 27 of Set 4 | west bay
# Processing Record 28 of Set 4 | leningradskiy
# Processing Record 29 of Set 4 | champerico
# Processing Record 30 of Set 4 | micheweni
# Processing Record 31 of Set 4 | tlacojalpan
# Processing Record 32 of Set 4 | merritt island
# Processing Record 33 of Set 4 | vestmannaeyjar
# Processing Record 34 of Set 4 | fasa
# Processing Record 35 of Set 4 | coquimbo
# Processing Record 36 of Set 4 | puerto del rosario
# Processing Record 37 of Set 4 | pontianak
# Processing Record 38 of Set 4 | sitamau
# Processing Record 39 of Set 4 | besancon
# Processing Record 40 of Set 4 | daru
# Processing Record 41 of Set 4 | karratha
# Processing Record 42 of Set 4 | chake chake
# Processing Record 43 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 44 of Set 4 | bambanglipuro
# Processing Record 45 of Set 4 | berlevag
# Processing Record 46 of Set 4 | gizo
# Processing Record 47 of Set 4 | longyearbyen
# Processing Record 48 of Set 4 | tura
# Processing Record 49 of Set 4 | comodoro rivadavia
# Processing Record 50 of Set 4 | qandala
# Processing Record 1 of Set 5 | hulan
# Processing Record 2 of Set 5 | iberia
# Processing Record 3 of Set 5 | half moon bay
# Processing Record 4 of Set 5 | san cristobal
# Processing Record 5 of Set 5 | manzhouli
# Processing Record 6 of Set 5 | killybegs
# Processing Record 7 of Set 5 | imbituba
# Processing Record 8 of Set 5 | cayenne
# Processing Record 9 of Set 5 | talcahuano
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | phulabani
# Processing Record 12 of Set 5 | cherskiy
# Processing Record 13 of Set 5 | nazareno
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | hofn
# Processing Record 16 of Set 5 | the valley
# Processing Record 17 of Set 5 | hambantota
# Processing Record 18 of Set 5 | sterling
# Processing Record 19 of Set 5 | saint-philippe
# Processing Record 20 of Set 5 | flin flon
# Processing Record 21 of Set 5 | barrow
# Processing Record 22 of Set 5 | santa marta
# Processing Record 23 of Set 5 | belmonte
# Processing Record 24 of Set 5 | vadso
# Processing Record 25 of Set 5 | singkang
# Processing Record 26 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 5 | mayo
# Processing Record 28 of Set 5 | turukhansk
# Processing Record 29 of Set 5 | tchibanga
# Processing Record 30 of Set 5 | chunoyar
# Processing Record 31 of Set 5 | marystown
# Processing Record 32 of Set 5 | kem
# Processing Record 33 of Set 5 | tiksi
# Processing Record 34 of Set 5 | khajuraho
# Processing Record 35 of Set 5 | nagpur
# Processing Record 36 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 5 | vilhena
# Processing Record 38 of Set 5 | port lincoln
# Processing Record 39 of Set 5 | lavrentiya
# Processing Record 40 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 5 | maku
# Processing Record 42 of Set 5 | chuy
# Processing Record 43 of Set 5 | makinsk
# Processing Record 44 of Set 5 | diamantino
# Processing Record 45 of Set 5 | jalu
# Processing Record 46 of Set 5 | shumskiy
# Processing Record 47 of Set 5 | ilulissat
# Processing Record 48 of Set 5 | vardo
# Processing Record 49 of Set 5 | saldanha
# Processing Record 50 of Set 5 | kupang
# Processing Record 1 of Set 6 | esperance
# Processing Record 2 of Set 6 | hasaki
# Processing Record 3 of Set 6 | tourlaville
# Processing Record 4 of Set 6 | lata
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | nuuk
# Processing Record 7 of Set 6 | kuzovatovo
# Processing Record 8 of Set 6 | riberalta
# Processing Record 9 of Set 6 | carutapera
# Processing Record 10 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 6 | tabukiniberu
# City not found. Skipping...
# Processing Record 12 of Set 6 | cockburn town
# Processing Record 13 of Set 6 | fort nelson
# Processing Record 14 of Set 6 | iwanai
# Processing Record 15 of Set 6 | tiznit
# Processing Record 16 of Set 6 | trapani
# Processing Record 17 of Set 6 | yerbogachen
# Processing Record 18 of Set 6 | port blair
# Processing Record 19 of Set 6 | manacapuru
# Processing Record 20 of Set 6 | faanui
# Processing Record 21 of Set 6 | cidreira
# Processing Record 22 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 6 | itacare
# Processing Record 24 of Set 6 | aquiraz
# Processing Record 25 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 6 | yashkul
# Processing Record 27 of Set 6 | yuancheng
# Processing Record 28 of Set 6 | oktyabrskiy
# Processing Record 29 of Set 6 | agva
# City not found. Skipping...
# Processing Record 30 of Set 6 | mombetsu
# Processing Record 31 of Set 6 | datong
# Processing Record 32 of Set 6 | santa cruz de tenerife
# Processing Record 33 of Set 6 | batemans bay
# Processing Record 34 of Set 6 | boa vista
# Processing Record 35 of Set 6 | maragogi
# Processing Record 36 of Set 6 | olafsvik
# Processing Record 37 of Set 6 | snasa
# Processing Record 38 of Set 6 | geraldton
# Processing Record 39 of Set 6 | muzhi
# Processing Record 40 of Set 6 | kavieng
# Processing Record 41 of Set 6 | kirkcudbright
# Processing Record 42 of Set 6 | mount gambier
# Processing Record 43 of Set 6 | pisco
# Processing Record 44 of Set 6 | kurilsk
# Processing Record 45 of Set 6 | tuatapere
# Processing Record 46 of Set 6 | tazovskiy
# Processing Record 47 of Set 6 | olinda
# Processing Record 48 of Set 6 | jawhar
# Processing Record 49 of Set 6 | severo-kurilsk
# Processing Record 50 of Set 6 | fushun
# Processing Record 1 of Set 7 | jinchang
# Processing Record 2 of Set 7 | lorengau
# Processing Record 3 of Set 7 | shenjiamen
# Processing Record 4 of Set 7 | polis
# Processing Record 5 of Set 7 | la ronge
# Processing Record 6 of Set 7 | okhotsk
# Processing Record 7 of Set 7 | abilene
# Processing Record 8 of Set 7 | sioux lookout
# Processing Record 9 of Set 7 | smithers
# Processing Record 10 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 7 | minna
# Processing Record 12 of Set 7 | teahupoo
# Processing Record 13 of Set 7 | bambous virieux
# Processing Record 14 of Set 7 | nelson bay
# Processing Record 15 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 7 | apac
# Processing Record 17 of Set 7 | atar
# Processing Record 18 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 7 | roseburg
# Processing Record 20 of Set 7 | lugovoy
# Processing Record 21 of Set 7 | hamada
# Processing Record 22 of Set 7 | jumla
# Processing Record 23 of Set 7 | bilma
# Processing Record 24 of Set 7 | tilichiki
# Processing Record 25 of Set 7 | fuyu
# Processing Record 26 of Set 7 | lock haven
# Processing Record 27 of Set 7 | asau
# Processing Record 28 of Set 7 | narsaq
# Processing Record 29 of Set 7 | nanortalik
# Processing Record 30 of Set 7 | constitucion
# Processing Record 31 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 32 of Set 7 | guayaramerin
# Processing Record 33 of Set 7 | el doncello
# Processing Record 34 of Set 7 | huaraz
# Processing Record 35 of Set 7 | isangel
# Processing Record 36 of Set 7 | pattoki
# Processing Record 37 of Set 7 | guerrero negro
# Processing Record 38 of Set 7 | douentza
# Processing Record 39 of Set 7 | beian
# Processing Record 40 of Set 7 | haines junction
# Processing Record 41 of Set 7 | belize
# Processing Record 42 of Set 7 | nicoya
# Processing Record 43 of Set 7 | taguatinga
# Processing Record 44 of Set 7 | churapcha
# Processing Record 45 of Set 7 | taoudenni
# Processing Record 46 of Set 7 | gao
# Processing Record 47 of Set 7 | college
# Processing Record 48 of Set 7 | balading
# Processing Record 49 of Set 7 | kriel
# Processing Record 50 of Set 7 | atasu
# Processing Record 1 of Set 8 | filingue
# Processing Record 2 of Set 8 | saint george
# Processing Record 3 of Set 8 | tupelo
# Processing Record 4 of Set 8 | colares
# Processing Record 5 of Set 8 | thohoyandou
# Processing Record 6 of Set 8 | bengkulu
# Processing Record 7 of Set 8 | sobolevo
# Processing Record 8 of Set 8 | rio gallegos
# Processing Record 9 of Set 8 | bismarck
# Processing Record 10 of Set 8 | oksfjord
# Processing Record 11 of Set 8 | vao
# Processing Record 12 of Set 8 | bani
# Processing Record 13 of Set 8 | amahai
# Processing Record 14 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 8 | zhezkazgan
# Processing Record 17 of Set 8 | coihaique
# Processing Record 18 of Set 8 | novaya zaimka
# Processing Record 19 of Set 8 | shimoda
# Processing Record 20 of Set 8 | miri
# Processing Record 21 of Set 8 | makakilo city
# Processing Record 22 of Set 8 | shibarghan
# City not found. Skipping...
# Processing Record 23 of Set 8 | anadyr
# Processing Record 24 of Set 8 | zhangjiakou
# Processing Record 25 of Set 8 | losone
# Processing Record 26 of Set 8 | paraiso
# Processing Record 27 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 8 | kitimat
# Processing Record 29 of Set 8 | areosa
# Processing Record 30 of Set 8 | salalah
# Processing Record 31 of Set 8 | sur
# Processing Record 32 of Set 8 | nizhniy kuranakh
# Processing Record 33 of Set 8 | tubmanburg
# Processing Record 34 of Set 8 | kirovskiy
# Processing Record 35 of Set 8 | pierre
# Processing Record 36 of Set 8 | raga
# Processing Record 37 of Set 8 | prijepolje
# Processing Record 38 of Set 8 | agadir
# Processing Record 39 of Set 8 | ravar
# Processing Record 40 of Set 8 | craig
# Processing Record 41 of Set 8 | axim
# Processing Record 42 of Set 8 | saint-pierre
# Processing Record 43 of Set 8 | naliya
# Processing Record 44 of Set 8 | caldwell
# Processing Record 45 of Set 8 | buraydah
# Processing Record 46 of Set 8 | maua
# Processing Record 47 of Set 8 | laguna
# Processing Record 48 of Set 8 | kasempa
# Processing Record 49 of Set 8 | mongoumba
# Processing Record 50 of Set 8 | hai duong
# Processing Record 1 of Set 9 | casas grandes
# Processing Record 2 of Set 9 | parobe
# Processing Record 3 of Set 9 | maryville
# Processing Record 4 of Set 9 | suntar
# Processing Record 5 of Set 9 | san pedro
# Processing Record 6 of Set 9 | husavik
# Processing Record 7 of Set 9 | sao joao da barra
# Processing Record 8 of Set 9 | salinopolis
# Processing Record 9 of Set 9 | zhigalovo
# Processing Record 10 of Set 9 | cururupu
# Processing Record 11 of Set 9 | ulladulla
# Processing Record 12 of Set 9 | bosaso
# Processing Record 13 of Set 9 | fairbanks
# Processing Record 14 of Set 9 | porto santo
# Processing Record 15 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 9 | popondetta
# Processing Record 17 of Set 9 | havoysund
# Processing Record 18 of Set 9 | darab
# Processing Record 19 of Set 9 | alugan
# Processing Record 20 of Set 9 | iquitos
# Processing Record 21 of Set 9 | manicore
# Processing Record 22 of Set 9 | wajir
# Processing Record 23 of Set 9 | barra patuca
# Processing Record 24 of Set 9 | orchard homes
# Processing Record 25 of Set 9 | vanimo
# Processing Record 26 of Set 9 | benguela
# Processing Record 27 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 28 of Set 9 | santa maria
# Processing Record 29 of Set 9 | padang
# Processing Record 30 of Set 9 | bo phloi
# Processing Record 31 of Set 9 | prince rupert
# Processing Record 32 of Set 9 | bar harbor
# Processing Record 33 of Set 9 | darnah
# Processing Record 34 of Set 9 | tautira
# Processing Record 35 of Set 9 | naze
# Processing Record 36 of Set 9 | beringovskiy
# Processing Record 37 of Set 9 | fortuna
# Processing Record 38 of Set 9 | ambon
# Processing Record 39 of Set 9 | sitka
# Processing Record 40 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 41 of Set 9 | grindavik
# Processing Record 42 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 43 of Set 9 | tuy hoa
# Processing Record 44 of Set 9 | ancud
# Processing Record 45 of Set 9 | minot
# Processing Record 46 of Set 9 | thunder bay
# Processing Record 47 of Set 9 | taree
# Processing Record 48 of Set 9 | biryusinsk
# Processing Record 49 of Set 9 | zarichne
# Processing Record 50 of Set 9 | oktyabrskoye
# Processing Record 1 of Set 10 | tromso
# Processing Record 2 of Set 10 | bitung
# Processing Record 3 of Set 10 | belaya gora
# Processing Record 4 of Set 10 | ibra
# Processing Record 5 of Set 10 | hokitika
# Processing Record 6 of Set 10 | tanout
# Processing Record 7 of Set 10 | piranshahr
# Processing Record 8 of Set 10 | brigantine
# Processing Record 9 of Set 10 | kahului
# Processing Record 10 of Set 10 | miyazu
# Processing Record 11 of Set 10 | miyako
# Processing Record 12 of Set 10 | perevolotskiy
# Processing Record 13 of Set 10 | goderich
# Processing Record 14 of Set 10 | ostrov
# Processing Record 15 of Set 10 | port hardy
# Processing Record 16 of Set 10 | morgan city
# Processing Record 17 of Set 10 | prainha
# Processing Record 18 of Set 10 | surgut
# Processing Record 19 of Set 10 | lac du bonnet
# Processing Record 20 of Set 10 | maceio
# Processing Record 21 of Set 10 | dzaoudzi
# Processing Record 22 of Set 10 | waipawa
# Processing Record 23 of Set 10 | hualmay
# Processing Record 24 of Set 10 | ikeda
# Processing Record 25 of Set 10 | blagoyevo
# Processing Record 26 of Set 10 | san rafael
# Processing Record 27 of Set 10 | nea apollonia
# Processing Record 28 of Set 10 | sal rei
# Processing Record 29 of Set 10 | buala
# Processing Record 30 of Set 10 | flinders
# Processing Record 31 of Set 10 | mount isa
# Processing Record 32 of Set 10 | bend
# Processing Record 33 of Set 10 | tarko-sale
# Processing Record 34 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 35 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 10 | pozo colorado
# Processing Record 37 of Set 10 | anahuac
# Processing Record 38 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 10 | bandarbeyla
# Processing Record 40 of Set 10 | acari
# Processing Record 41 of Set 10 | kolondieba
# Processing Record 42 of Set 10 | urumqi
# Processing Record 43 of Set 10 | kismayo
# Processing Record 44 of Set 10 | lethem
# Processing Record 45 of Set 10 | stoyba
# City not found. Skipping...
# Processing Record 46 of Set 10 | cabo san lucas
# Processing Record 47 of Set 10 | kutum
# Processing Record 48 of Set 10 | otradinskiy
# City not found. Skipping...
# Processing Record 49 of Set 10 | sidney
# Processing Record 50 of Set 10 | arkhangelsk
# Processing Record 1 of Set 11 | magaria
# Processing Record 2 of Set 11 | phan thiet
# Processing Record 3 of Set 11 | manohar thana
# Processing Record 4 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 11 | luderitz
# Processing Record 6 of Set 11 | peleduy
# Processing Record 7 of Set 11 | egvekinot
# Processing Record 8 of Set 11 | grand-lahou
# Processing Record 9 of Set 11 | kaura namoda
# Processing Record 10 of Set 11 | bandar penggaram
# City not found. Skipping...
# Processing Record 11 of Set 11 | port-gentil
# Processing Record 12 of Set 11 | freeport
# Processing Record 13 of Set 11 | bone
# Processing Record 14 of Set 11 | bantry
# Processing Record 15 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 16 of Set 11 | dawei
# Processing Record 17 of Set 11 | viedma
# Processing Record 18 of Set 11 | zonguldak
# Processing Record 19 of Set 11 | sayyan
# Processing Record 20 of Set 11 | ust-nera
# Processing Record 21 of Set 11 | krasnogvardeyskiy
# Processing Record 22 of Set 11 | katangli
# Processing Record 23 of Set 11 | saint-augustin
# Processing Record 24 of Set 11 | degtyarsk
# Processing Record 25 of Set 11 | victoria point
# Processing Record 26 of Set 11 | fonte boa
# Processing Record 27 of Set 11 | maragheh
# Processing Record 28 of Set 11 | ouadda
# Processing Record 29 of Set 11 | dessau
# Processing Record 30 of Set 11 | pucallpa
# Processing Record 31 of Set 11 | touros
# Processing Record 32 of Set 11 | mercedes
# Processing Record 33 of Set 11 | baghdad
# Processing Record 34 of Set 11 | pueblo nuevo
# Processing Record 35 of Set 11 | itoman
# Processing Record 36 of Set 11 | ossora
# Processing Record 37 of Set 11 | tamandare
# Processing Record 38 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 39 of Set 11 | lompoc
# Processing Record 40 of Set 11 | vostok
# Processing Record 41 of Set 11 | buta
# Processing Record 42 of Set 11 | zyryanskoye
# Processing Record 43 of Set 11 | fare
# Processing Record 44 of Set 11 | kailua
# Processing Record 45 of Set 11 | trincomalee
# Processing Record 46 of Set 11 | ahtopol
# Processing Record 47 of Set 11 | koppang
# Processing Record 48 of Set 11 | isla mujeres
# Processing Record 49 of Set 11 | redcliffe
# Processing Record 50 of Set 11 | farafangana
# Processing Record 1 of Set 12 | vagur
# Processing Record 2 of Set 12 | antofagasta
# Processing Record 3 of Set 12 | mokhsogollokh
# Processing Record 4 of Set 12 | sorland
# Processing Record 5 of Set 12 | jaunjelgava
# Processing Record 6 of Set 12 | dutse
# Processing Record 7 of Set 12 | manglaur
# Processing Record 8 of Set 12 | anito
# Processing Record 9 of Set 12 | sistranda
# Processing Record 10 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 12 | lincoln
# Processing Record 12 of Set 12 | sevojno
# Processing Record 13 of Set 12 | douglas
# Processing Record 14 of Set 12 | leh
# Processing Record 15 of Set 12 | myingyan
# Processing Record 16 of Set 12 | cap malheureux
# Processing Record 17 of Set 12 | tabou
# Processing Record 18 of Set 12 | minanga
# Processing Record 19 of Set 12 | kamenka
# Processing Record 20 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 21 of Set 12 | sinegorye
# Processing Record 22 of Set 12 | amapa
# Processing Record 23 of Set 12 | paragominas
# Processing Record 24 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 25 of Set 12 | aswan
# Processing Record 26 of Set 12 | tecpan
# Processing Record 27 of Set 12 | barraute
# Processing Record 28 of Set 12 | sula
# Processing Record 29 of Set 12 | whitehorse
# Processing Record 30 of Set 12 | port hedland
# Processing Record 31 of Set 12 | auki
# Processing Record 32 of Set 12 | emba
# Processing Record 33 of Set 12 | karlskoga
# Processing Record 34 of Set 12 | iskateley
# Processing Record 35 of Set 12 | dryden
# Processing Record 36 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 12 | el badari
# City not found. Skipping...
# Processing Record 38 of Set 12 | beroroha
# Processing Record 39 of Set 12 | luebo
# Processing Record 40 of Set 12 | katobu
# Processing Record 41 of Set 12 | kangaba
# Processing Record 42 of Set 12 | yuzhnyy
# Processing Record 43 of Set 12 | coahuayana
# Processing Record 44 of Set 12 | lodwar
# Processing Record 45 of Set 12 | mackay
# Processing Record 46 of Set 12 | kirensk
# Processing Record 47 of Set 12 | la plata
# Processing Record 48 of Set 12 | samarai
# Processing Record 49 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 50 of Set 12 | srednekolymsk
# Processing Record 1 of Set 13 | olmos
# Processing Record 2 of Set 13 | eureka
# Processing Record 3 of Set 13 | baykit
# Processing Record 4 of Set 13 | caravelas
# Processing Record 5 of Set 13 | moose factory
# Processing Record 6 of Set 13 | pyay
# Processing Record 7 of Set 13 | puerto cortes
# City not found. Skipping...
# Processing Record 8 of Set 13 | teneguiban
# City not found. Skipping...
# Processing Record 9 of Set 13 | aleksandrovskoye
# Processing Record 10 of Set 13 | ingham
# Processing Record 11 of Set 13 | encruzilhada do sul
# Processing Record 12 of Set 13 | warmbad
# Processing Record 13 of Set 13 | sri aman
# Processing Record 14 of Set 13 | severnyy
# Processing Record 15 of Set 13 | sisimiut
# Processing Record 16 of Set 13 | simitli
# Processing Record 17 of Set 13 | itarema
# Processing Record 18 of Set 13 | porangatu
# Processing Record 19 of Set 13 | faya
# Processing Record 20 of Set 13 | ueki
# Processing Record 21 of Set 13 | gornopravdinsk
# Processing Record 22 of Set 13 | gat
# Processing Record 23 of Set 13 | lagunas
# Processing Record 24 of Set 13 | lasa
# Processing Record 25 of Set 13 | darhan
# Processing Record 26 of Set 13 | green river
# Processing Record 27 of Set 13 | beipiao
# Processing Record 28 of Set 13 | midland
# Completed

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Creat a dictionary for the weather data
Weather_data = {
    "City": cities_list,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

# Dataframe

Weather_df = pd.DataFrame(Weather_data)
Weather_df.count()
# Out:
# City          577
# Cloudiness    577
# Country       577
# Date          577
# Humidity      577
# Lat           577
# Lng           577
# Max Temp      577
# Wind Speed    577
# dtype: int64

# %%
Weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0  Punta Arenas          75      CL  1584464171        54 -53.15 -70.92
# 1      Tessalit          35      ML  1584464285        10  20.20   1.01
# 2      Klaksvík          23      FO  1584464285        69  62.23  -6.59
# 3     Cape Town          13      ZA  1584463861        73 -33.93  18.42
# 4       Neuquén           0      AR  1584464131        27 -38.95 -68.06
#
#    Max Temp  Wind Speed
# 0     53.60       27.07
# 1     92.21       16.02
# 2     39.20       17.22
# 3     70.00       16.11
# 4     78.80        4.70

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Scatter plot Latitude vs. Temperature
plt.scatter(Weather_df["Lat"], Weather_df["Max Temp"], edgecolor="black")
plt.title("Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temp. (F)")
plt.savefig("Images/temperature.png")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Scatter plot Latitude vs. Humidity
plt.scatter(Weather_df["Lat"], Weather_df["Humidity"], edgecolor="black")
plt.title("Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("Images/humidity.png")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Scatter plot Latitude vs. Cloudiness
plt.scatter(Weather_df["Lat"], Weather_df["Cloudiness"], edgecolor="black")
plt.title("Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("Images/cloudiness.png")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Scatter plot Latitude vs. Wind Speed
plt.scatter(Weather_df["Lat"], Weather_df["Wind Speed"], edgecolor="black")
plt.title("Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.savefig("Images/Wind Speed.png")
plt.grid()
plt.show()

# %%
# converting the DataFrame to a csv file
Weather_df.to_csv("Data/weather_data.csv",index=False, header=True)

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
